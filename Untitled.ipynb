# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import StandardScaler,RobustScaler,MinMaxScaler,Normalizer,OneHotEncoder
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from sklearn.tree import DecisionTreeRegressor
import xgboost 
from sklearn.linear_model import LinearRegression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import pickle

# %%
tt=readdata()
tt.columns
# Out:
# Index(['Ship Mode', 'Segment', 'City', 'State', 'Postal Code', 'Region',
#        'Category', 'Sub-Category', 'Product Name', 'Sales', 'Quantity',
#        'Discount', 'Profit', 'Shipping_days'],
#       dtype='object')

# %%
def readdata():
    data=pd.read_excel('Sample - Superstore.xls')
    data['Shipping_days']=(data['Ship Date']-data['Order Date']).dt.days
    data.drop(['Row ID','Order ID', 'Order Date','Product ID', 'Ship Date','Customer ID','Customer Name'],axis=1,inplace=True)
    data.drop('Country',axis=1,inplace=True)
    global categorical_columns
    global numerical_columns
    categorical_columns=data.select_dtypes(include='object').columns
    numerical_columns=data.select_dtypes(exclude='object').columns
    return data

# %%
ohe=OneHotEncoder(sparse=False,drop='first')
def preprocessing(data):
    onehotencoded=ohe.fit_transform(data[categorical_columns.drop([ 'City','State','Sub-Category', 'Product Name'])])
    columns=ohe.get_feature_names_out()
    data[columns]=onehotencoded
    data.drop(categorical_columns.drop(['City','State','Sub-Category', 'Product Name']),axis=1,inplace=True)
    global encoded
    encoded=[]
    for column in ['City','State','Sub-Category', 'Product Name','Postal Code']:
        col_encoded=data.groupby(column)['Sales'].agg('median').sort_values(ascending=True).to_dict()
        data[column]=data[column].map(col_encoded)
        cat_encoded={column:col_encoded}
        encoded.append(cat_encoded)
    return data

# %%
# def model():
#     X=data.drop(['Sales','Profit'],axis=1)
#     y=data[['Sales']]
#     standard=StandardScaler()
#     robust=RobustScaler()
#     minmax=MinMaxScaler()
#     normalize=Normalizer()
#     IQR=X['Profit'].quantile(0.75)-X['Profit'].quantile(0.25)
#     upper_threshold=X['Profit'].median()+90*IQR
#     lower_threshold=X['Profit'].median()-90*IQR
#     X['Profit']=np.where(X['Profit']>upper_threshold,upper_threshold,X['Profit'])
#     X['Profit']=np.where(X['Profit']<lower_threshold,lower_threshold,X['Profit'])
#     for columns in X.iloc[:,:5].drop(['Quantity','Profit','Discount'],axis=1).columns:
#         X[columns]=np.log1p(X[columns])
#     upper_boundary=y.mean()+6*y.std()
#     y['Sales']=np.where(y>upper_boundary,upper_boundary,y)

# %%
def modeltraining(data):
    X=data.drop(['Sales','Profit'],axis=1)
    y=data[['Sales']]
    standard=StandardScaler()
    robust=RobustScaler()
    minmax=MinMaxScaler()
    normalize=Normalizer()
    for columns in ['City', 'Postal Code']:
        X[columns]=np.log1p(X[columns])
    for columns in ['Sub-Category', 'Product Name','Discount']:
        X[columns]=boxcox(X[columns]+.00001)[0]
    X['State']=1/X['State']
    upper_boundary=y.mean()+6*y.std()
    y['Sales']=np.where(y>upper_boundary,upper_boundary,y)
    return X,y

# %%
from sklearn.feature_selection import SelectKBest,f_regression
Selector=SelectKBest(score_func=f_regression,k=14)
def featureselection(X,y):
    Selector.fit(X,y)
    X_new=Selector.fit_transform(X,y)
    X_new=pd.DataFrame(Selector.fit_transform(X,y),columns=X.columns[Selector.get_support()])
    X_train,X_test,y_train,y_test=train_test_split(X_new,y,test_size=0.3,random_state=42)
    return X_train,X_test,y_train,y_test

# %%
def modelprediction(X_test):
    xgboost_model=pickle.load(open('xgboost.pkl','rb'))
    xgboost_pred=xgboost_model.predict(X_test)
    return xgboost_pred

# %%
def model():
    df=readdata()
    df=preprocessing(df)
    X,y=modeltraining(df)
    X_train,X_test,y_train,y_test=featureselection(X,y)
    return X_train,X_test,y_train,y_test

# %%
X_train,X_test,y_train,y_test=model()

# %%
def predict():
    X_train,X_test,y_train,y_test=model()
    predictions=modelprediction(X_test)
    return predictions

# %%
Y_pred=predict()
Y_pred
# Out:
# array([562.5938  ,  43.40212 ,  30.914152, ...,  16.89179 , 331.17508 ,
#         60.96805 ], dtype=float32)

# %%
y_test['pred']=Y_pred

# %%
y_test
# Out:
#         Sales        pred
# 3125  563.808  562.593811
# 1441   36.672   43.402119
# 4510   37.300   30.914152
# 39    212.058  261.018616
# 4509  171.288  232.642517
# ...       ...         ...
# 9063  322.192  195.457855
# 2603  136.784  157.625443
# 6112   16.752   16.891790
# 1579  307.980  331.175079
# 9884   62.310   60.968048
#
# [2999 rows x 2 columns]

# %%
def testmodel(data):
    onehotencoded=ohe.transform(data[['Ship Mode', 'Segment', 'Region', 'Category']])
    columns=ohe.get_feature_names_out()
    data[columns]=onehotencoded
    data.drop(['Ship Mode', 'Segment', 'Region', 'Category'],axis=1,inplace=True)
    for category in encoded:
        for column,values in category.items():
            data[column]=data[column].map(values)
    X=data.copy()
    for columns in ['City', 'Postal Code']:
        X[columns]=np.log1p(X[columns])
    X['State']=1/X['State']
    df=readdata()
    X2=preprocessing(df)
    for columns in ['Sub-Category', 'Product Name','Discount']:
        X2[columns],lmbda=boxcox(X2[columns]+.00001)
        if lmbda==0:
            X[columns]=log(X[columns]+0.00001)
        else:
            X[columns]=((X[columns]+0.00001)**lmbda-1)/lmbda
    X_new=pd.DataFrame(X,columns=X.columns[Selector.get_support()])
    Predicition=modelprediction(X_new)
    return round(Predicition[0],2)

# %%
a=dict(zip(ohe.feature_names_in_,ohe.categories_))
a
# Out:
# {'Ship Mode': array(['First Class', 'Same Day', 'Second Class', 'Standard Class'],
#        dtype=object),
#  'Segment': array(['Consumer', 'Corporate', 'Home Office'], dtype=object),
#  'Region': array(['Central', 'East', 'South', 'West'], dtype=object),
#  'Category': array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)}

# %%
Ship_Mode=[]
Segment=[]
Region=[]
Category=[]
a=dict(zip(ohe.feature_names_in_,ohe.categories_))
for category,value in a.items():
    if category=='Ship Mode':
        Ship_Mode.extend(value)
    elif category=='Segment':
        Segment.extend(value)
    elif category=='Region':
        Region.extend(value)
    else:
        Category.extend(value)
print(Ship_Mode)
# Out:
# ['First Class', 'Same Day', 'Second Class', 'Standard Class']

# %%
X_train.columns
# Out:
# Index(['City', 'State', 'Postal Code', 'Sub-Category', 'Product Name',
#        'Quantity', 'Discount', 'Shipping_days', 'Ship Mode_Second Class',
#        'Ship Mode_Standard Class', 'Segment_Corporate', 'Region_East',
#        'Category_Office Supplies', 'Category_Technology'],
#       dtype='object')

# %%
test_frame={'Ship Mode': 'First Class',
 'Segment': 'Corporate',
 'City': 'Lakeland',
 'State': 'Florida',
 'Postal Code': 33801,
 'Region': 'South',
 'Category': 'Office Supplies',
 'Sub-Category': 'Storage',
 'Product Name': 'Fellowes High-Stak Drawer Files',
 'Quantity': 4,
 'Discount': 0.2,
 'Shipping_days':1}
test=pd.DataFrame([test_frame])
test
# Out:
#      Ship Mode    Segment      City    State  Postal Code Region  \
# 0  First Class  Corporate  Lakeland  Florida        33801  South
#
#           Category Sub-Category                     Product Name  Quantity  \
# 0  Office Supplies      Storage  Fellowes High-Stak Drawer Files         4
#
#    Discount  Shipping_days
# 0       0.2              1

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   City                      1 non-null      float64
#  1   State                     1 non-null      float64
#  2   Postal Code               1 non-null      float64
#  3   Sub-Category              1 non-null      float64
#  4   Product Name              1 non-null      float64
#  5   Quantity                  1 non-null      int64
#  6   Discount                  1 non-null      float64
#  7   Shipping_days             1 non-null      int64
#  8   Ship Mode_Same Day        1 non-null      float64
#  9   Ship Mode_Second Class    1 non-null      float64
#  10  Ship Mode_Standard Class  1 non-null      float64
#  11  Segment_Corporate         1 non-null      float64
#  12  Segment_Home Office       1 non-null      float64
#  13  Region_East               1 non-null      float64
#  14  Region_South              1 non-null      float64
#  15  Region_West               1 non-null      float64
#  16  Category_Office Supplies  1 non-null      float64
#  17  Category_Technology       1 non-null      float64
# dtypes: float64(16), int64(2)
# memory usage: 272.0 bytes

# %%
Test_predicition=testmodel(test)
Test_predicition
# Out:
# 562.59

# %%
City = []
State = []
Postal_Code = []
Sub_Category = []
Product_Name = []
for column in encoded:
    for key, values in column.items():
        for category in sorted(values.keys()):
            if key == 'City':
                City.append(category)
            elif key == 'State':
                State.append(category)
            elif key == 'Postal Code':
                Postal_Code.append(category)
            elif key == 'Sub-Category':
                Sub_Category.append(category)
            else:
                Product_Name.append(category)
City

# %%
encoded
# Out:
# [{'City': {'Abilene': 1.3919999999999997,
#    'Elyria': 1.8240000000000003,
#    'Jupiter': 2.064,
#    'Pensacola': 2.2140000000000004,
#    'Edinburg': 2.368,
#    'Ormond Beach': 2.8080000000000007,
#    'San Luis Obispo': 3.62,
#    'Springdale': 4.3,
#    'Layton': 4.96,
#    'Loveland': 5.496,
#    'Mesquite': 5.5440000000000005,
#    'Keller': 6.0,
#    'Missouri City': 6.369999999999998,
#    'Deer Park': 6.923999999999998,
#    'New Brunswick': 7.385,
#    'Port Orange': 7.824,
#    'Billings': 8.288,
#    'Cuyahoga Falls': 8.352,
#    'Romeoville': 8.951999999999998,
#    'Garden City': 9.54,
#    'Iowa City': 9.99,
#    'Altoona': 10.2255,
#    'Baytown': 10.368000000000002,
#    'North Miami': 11.064000000000002,
#    'Bullhead City': 11.144000000000002,
#    'Bolingbrook': 11.200000000000001,
#    'Huntington Beach': 11.67,
#    'Rock Hill': 11.850000000000001,
#    'Broken Arrow': 11.88,
#    'Hendersonville': 12.264,
#    'Tempe': 12.768,
#    'Beaumont': 12.768,
#    'Oswego': 13.16,
#    'Corpus Christi': 13.212,
#    'Mcallen': 13.344000000000001,
#    'Pearland': 13.392000000000001,
#    'Chapel Hill': 14.015999999999998,
#    'Woodstock': 14.04,
#    'Arlington Heights': 14.111999999999998,
#    'Port Saint Lucie': 14.336000000000002,
#    'Murfreesboro': 14.352000000000002,
#    'Garland': 14.388,
#    'Coppell': 14.952000000000002,
#    'Bryan': 14.960999999999997,
#    'Greeley': 15.176,
#    'Arvada': 15.184000000000001,
#    'Hillsboro': 15.32,
#    'Waco': 15.544000000000002,
#    'Margate': 15.552000000000003,
#    'Hollywood': 15.570000000000004,
#    'San Marcos': 15.576000000000002,
#    'Laredo': 15.872,
#    'Grand Island': 15.96,
#    'Asheville': 16.272000000000002,
#    'Portage': 16.28,
#    'Norwich': 16.770000000000003,
#    'Norfolk': 17.43,
#    'Bellevue': 17.608,
#    'Royal Oak': 17.67,
#    'Port Arthur': 17.688000000000002,
#    'Niagara Falls': 17.712,
#    'Nashua': 17.97,
#    'Riverside': 18.02,
#    'Lubbock': 18.262,
#    'Carlsbad': 18.45,
#    'Boca Raton': 18.464,
#    'Allen': 18.708000000000002,
#    'Leominster': 18.725,
#    'Sterling Heights': 19.0,
#    'Antioch': 19.44,
#    'Palm Coast': 19.52,
#    'Carrollton': 19.567999999999998,
#    'Lewiston': 19.712,
#    'Thornton': 20.048000000000002,
#    'Sheboygan': 20.085,
#    'Coral Springs': 20.192,
#    'Hickory': 20.382,
#    'Holland': 20.439999999999998,
#    'Hoover': 20.725,
#    'Grapevine': 20.764000000000003,
#    'Green Bay': 20.84,
#    'Woodland': 20.928,
#    'Bedford': 20.96,
#    'Meriden': 21.400000000000002,
#    'Pueblo': 21.534000000000002,
#    'Allentown': 21.728,
#    'Bozeman': 21.83,
#    'Tinley Park': 22.288,
#    'Mason': 22.428000000000004,
#    'Thousand Oaks': 22.72,
#    'New Bedford': 23.18,
#    'Vallejo': 23.344,
#    'Atlantic City': 23.36,
#    'Escondido': 23.36,
#    'Eagan': 23.625,
#    'Pompano Beach': 23.680000000000003,
#    'Medford': 23.78,
#    'Reading': 23.968000000000004,
#    'Johnson City': 24.184,
#    'Santa Clara': 24.456000000000003,
#    'Visalia': 24.560000000000002,
#    'Fort Worth': 24.587999999999994,
#    'Longview': 24.849999999999998,
#    'Aberdeen': 25.5,
#    'Dublin': 25.544000000000004,
#    'Akron': 25.560000000000002,
#    'Fargo': 25.9,
#    'Sandy Springs': 25.994999999999997,
#    'Bridgeton': 26.205000000000002,
#    'Boynton Beach': 26.488500000000002,
#    'Orange': 26.685000000000002,
#    'Apopka': 27.018000000000008,
#    'Alexandria': 27.025,
#    'Haltom City': 27.368000000000002,
#    'Danbury': 27.46,
#    'Parker': 27.706000000000003,
#    'Salem': 27.874000000000002,
#    'Montebello': 27.88,
#    'Quincy': 28.22,
#    'Chicago': 28.479999999999997,
#    'Grand Prairie': 28.752000000000002,
#    'Frisco': 28.752000000000002,
#    'La Porte': 29.13,
#    'Auburn': 29.255000000000003,
#    'College Station': 29.311999999999994,
#    'Wausau': 29.605,
#    'Hot Springs': 29.994999999999997,
#    'Skokie': 30.016000000000005,
#    'Sierra Vista': 30.144000000000002,
#    'Waterloo': 30.32,
#    'Toledo': 30.772000000000006,
#    'Plantation': 30.880000000000003,
#    'Cincinnati': 30.96,
#    'Wilson': 31.128000000000007,
#    'Redmond': 31.32,
#    'Overland Park': 31.365000000000002,
#    'Hialeah': 31.9805,
#    'Sacramento': 31.983999999999998,
#    'Coral Gables': 32.123999999999995,
#    'Omaha': 32.235,
#    'Roseville': 32.33,
#    'Knoxville': 32.348,
#    'Davis': 32.400000000000006,
#    'Redlands': 32.65,
#    'Rochester': 32.67,
#    'Greensboro': 32.776,
#    'San Bernardino': 33.36,
#    'Broomfield': 33.48800000000001,
#    'Salinas': 34.34,
#    'East Orange': 34.650000000000006,
#    'Vineland': 34.67,
#    'Andover': 34.87,
#    'Goldsboro': 34.944,
#    'Provo': 34.992000000000004,
#    'Dallas': 35.184,
#    'Owensboro': 35.59,
#    'Avondale': 35.596000000000004,
#    'Washington': 35.8,
#    'Dover': 35.88,
#    'Jacksonville': 36.112,
#    'Peoria': 36.28800000000001,
#    'Chico': 36.44,
#    'Rancho Cucamonga': 36.576,
#    'Midland': 36.63,
#    'Shelton': 36.665,
#    'Cary': 36.72800000000001,
#    'Laguna Niguel': 37.02,
#    'Saint Petersburg': 37.112,
#    'Oceanside': 37.209999999999994,
#    'Miami': 37.608000000000004,
#    'Houston': 37.839999999999996,
#    'Irving': 38.92999999999999,
#    'Daytona Beach': 39.096000000000004,
#    'Moreno Valley': 39.468,
#    'Malden': 39.68,
#    'Orlando': 39.72,
#    'Woodbury': 39.900000000000006,
#    'Meridian': 39.95,
#    'Troy': 40.2,
#    'Rogers': 40.410000000000004,
#    'Des Moines': 40.46,
#    'Philadelphia': 40.775999999999996,
#    'Milford': 41.265,
#    'Las Cruces': 41.37,
#    'Hempstead': 41.4,
#    'Bloomington': 41.552,
#    'Taylor': 41.9,
#    'Redwood City': 41.904,
#    'Plainfield': 41.95,
#    'New Castle': 42.305,
#    'Mentor': 42.467,
#    'Odessa': 42.784,
#    'Lawrence': 42.97,
#    'Glendale': 42.976,
#    'Sioux Falls': 43.0,
#    'Apple Valley': 43.176,
#    'Cambridge': 43.33,
#    'Danville': 43.37199999999999,
#    'Hagerstown': 43.8,
#    'Fairfield': 43.8,
#    'Westland': 43.92,
#    'Vancouver': 44.02,
#    'Bakersfield': 44.136,
#    'Homestead': 44.384,
#    'Kenner': 44.660000000000004,
#    'League City': 44.716,
#    'Fayetteville': 44.784,
#    'Richmond': 44.83,
#    'Decatur': 44.95,
#    'San Clemente': 45.028999999999996,
#    'Lakewood': 45.480000000000004,
#    'Wilmington': 45.56999999999999,
#    'Tampa': 45.59400000000001,
#    'Chester': 45.61600000000001,
#    'Urbandale': 45.92,
#    'La Quinta': 46.32,
#    'Cranston': 46.345,
#    'Freeport': 46.534000000000006,
#    'Arlington': 46.752,
#    'Phoenix': 46.872,
#    'Lakeville': 47.18,
#    'Lansing': 47.36,
#    'Superior': 47.400000000000006,
#    'El Paso': 47.51599999999999,
#    'Tigard': 47.70400000000001,
#    'Oxnard': 47.9,
#    'Delray Beach': 47.92,
#    'Fort Collins': 47.984,
#    'Austin': 47.984,
#    'Middletown': 48.16,
#    'Raleigh': 48.384,
#    'Woonsocket': 48.614999999999995,
#    'Memphis': 48.656000000000006,
#    'Gulfport': 48.69,
#    'Macon': 48.8,
#    'Frankfort': 48.816,
#    'Lorain': 48.896,
#    'San Francisco': 49.159,
#    'Westfield': 49.3,
#    'Chandler': 49.792,
#    'Lancaster': 50.415000000000006,
#    'Santa Fe': 50.46,
#    'Yucaipa': 50.8,
#    'Newport News': 50.95,
#    'Columbus': 50.965,
#    'Marysville': 51.09,
#    'Tyler': 51.18399999999998,
#    'Charlottesville': 51.305,
#    'Lake Charles': 51.96,
#    'Thomasville': 52.136,
#    'Colorado Springs': 52.416000000000004,
#    'Saint Louis': 52.59,
#    'Pasadena': 52.684,
#    'Harlingen': 53.42400000000001,
#    'Edmonds': 54.042,
#    'Pembroke Pines': 54.224000000000004,
#    'Waukesha': 54.5,
#    'Grand Rapids': 54.900000000000006,
#    'Lindenhurst': 55.48,
#    'Long Beach': 55.6,
#    'Clovis': 55.71,
#    'Westminster': 55.76,
#    'Saint Charles': 55.83,
#    'West Palm Beach': 55.98400000000001,
#    'Monroe': 56.3,
#    'New Albany': 56.699999999999996,
#    'Redondo Beach': 57.084,
#    'Fremont': 57.12,
#    'Ann Arbor': 57.959999999999994,
#    'Trenton': 58.050000000000004,
#    'Cleveland': 58.141000000000005,
#    'Lakeland': 58.356,
#    'Yonkers': 59.519999999999996,
#    'Jackson': 59.61,
#    'The Colony': 59.751999999999995,
#    'Orem': 59.80800000000001,
#    'Jonesboro': 59.98,
#    'Waterbury': 59.98,
#    'Utica': 60.235,
#    'New Rochelle': 60.72,
#    'Little Rock': 60.989999999999995,
#    'Henderson': 61.0,
#    'Cedar Hill': 61.188,
#    'New York City': 61.44,
#    'Durham': 61.568,
#    'Grove City': 61.79399999999999,
#    'Revere': 61.96,
#    'Englewood': 62.028,
#    'Logan': 62.048,
#    'Springfield': 62.099999999999994,
#    'Tallahassee': 62.19200000000001,
#    'Medina': 62.982,
#    'Tulsa': 63.81,
#    'Bayonne': 63.96,
#    'Helena': 63.980000000000004,
#    'Maple Grove': 64.475,
#    'Nashville': 64.784,
#    'Las Vegas': 64.9,
#    'Rome': 64.981,
#    'York': 65.584,
#    'Seattle': 65.64,
#    'Hamilton': 65.664,
#    'Paterson': 65.84,
#    'Salt Lake City': 65.86,
#    'West Jordan': 66.69,
#    'Columbia': 67.13600000000001,
#    'Minneapolis': 67.15,
#    'Belleville': 67.255,
#    'Marion': 67.303,
#    'Atlanta': 67.8,
#    'Charlotte': 67.9425,
#    'Saginaw': 68.105,
#    'Greenville': 68.112,
#    'Lodi': 68.49,
#    'La Crosse': 68.64,
#    'Clarksville': 69.21600000000001,
#    'Los Angeles': 69.456,
#    'Dearborn Heights': 70.09,
#    'Bristol': 70.55999999999999,
#    'Mobile': 70.98,
#    'Murray': 71.92800000000001,
#    'Kent': 71.976,
#    'Cottage Grove': 72.17999999999999,
#    'Littleton': 72.29400000000001,
#    'Suffolk': 72.43,
#    'Covington': 73.45,
#    'Aurora': 73.87299999999999,
#    'Baltimore': 74.0,
#    'Smyrna': 74.087,
#    'Morristown': 74.45,
#    'East Point': 75.0,
#    'Huntsville': 75.04400000000001,
#    'San Mateo': 75.17999999999999,
#    'Brentwood': 75.938,
#    'Laurel': 76.295,
#    'Rapid City': 76.32000000000001,
#    'Eugene': 76.368,
#    'Lake Forest': 76.37,
#    'Round Rock': 78.85279999999999,
#    'Clinton': 79.36,
#    'Naperville': 79.476,
#    'Fresno': 79.91,
#    'Florence': 79.96,
#    'Lafayette': 81.4,
#    'Mesa': 81.6515,
#    'Coachella': 81.775,
#    'Wichita': 81.96,
#    'Gladstone': 82.17,
#    'Reno': 82.239,
#    'Gilbert': 82.368,
#    'San Diego': 83.328,
#    'Newark': 83.92,
#    'Elkhart': 85.715,
#    'Sparks': 86.19999999999999,
#    'Jefferson City': 86.62,
#    'Parma': 87.032,
#    'Lowell': 87.725,
#    'Tuscaloosa': 87.85000000000001,
#    'Oakland': 88.48700000000001,
#    'Bartlett': 88.96000000000001,
#    'Louisville': 89.99100000000001,
#    'Bossier City': 90.42999999999999,
#    'Rockville': 90.48,
#    'Caldwell': 91.36,
#    'San Jose': 91.8565,
#    'Milwaukee': 92.52,
#    'Chattanooga': 93.72550000000001,
#    'Melbourne': 95.616,
#    'Tucson': 95.989,
#    'Plano': 95.992,
#    'North Las Vegas': 96.18,
#    'Great Falls': 96.332,
#    'Saint Paul': 96.41499999999999,
#    'Sunnyvale': 97.175,
#    'Denver': 98.233,
#    'Bethlehem': 99.372,
#    'Concord': 99.592,
#    'San Antonio': 99.918,
#    'Burlington': 99.98,
#    'Pomona': 99.98,
#    'Santa Ana': 100.126,
#    'South Bend': 102.285,
#    'Marlborough': 103.32,
#    'Roswell': 104.13,
#    'Albuquerque': 104.525,
#    'Manchester': 104.79,
#    'Franklin': 106.05,
#    'Pine Bluff': 106.45500000000001,
#    'Olathe': 107.94,
#    'Deltona': 107.97600000000001,
#    'Scottsdale': 110.304,
#    'Providence': 110.98,
#    'Conroe': 111.67200000000001,
#    'Modesto': 111.79,
#    'Draper': 111.93,
#    'Warwick': 111.96,
#    'Sanford': 112.77300000000001,
#    'Bowling Green': 113.15600000000002,
#    'Yuma': 115.19200000000001,
#    'Linden': 115.36,
#    'Santa Maria': 115.44,
#    'Palatine': 116.312,
#    'Fort Lauderdale': 116.75999999999999,
#    'Athens': 117.445,
#    'Greenwood': 117.87,
#    'Madison': 119.585,
#    'Costa Mesa': 119.61600000000001,
#    'Encinitas': 119.83299999999998,
#    'Mission Viejo': 120.0,
#    'Kirkwood': 120.67,
#    'Everett': 121.25,
#    'Wheeling': 121.536,
#    'Oklahoma City': 121.6,
#    'Georgetown': 121.92999999999999,
#    'Manteca': 122.352,
#    'Harrisonburg': 122.48,
#    'Inglewood': 122.59,
#    'Anaheim': 122.688,
#    'Camarillo': 122.91,
#    'Detroit': 123.858,
#    'Elmhurst': 123.924,
#    'West Allis': 125.24000000000001,
#    'Indianapolis': 125.88,
#    'Morgan Hill': 127.193,
#    'Stockton': 127.86,
#    'Rockford': 128.744,
#    'Citrus Heights': 129.39000000000001,
#    'Portland': 131.264,
#    'Rochester Hills': 132.52,
#    'Muskogee': 137.61,
#    'Pocatello': 140.376,
#    'North Charleston': 142.125,
#    'Amarillo': 142.42239999999998,
#    'Temecula': 142.54500000000002,
#    'Watertown': 144.003,
#    'Waynesboro': 144.1,
#    'Virginia Beach': 144.41500000000002,
#    'Pico Rivera': 145.9,
#    'Commerce City': 146.352,
#    'Spokane': 149.73000000000002,
#    'Hackensack': 150.65499999999997,
#    'Miramar': 150.712,
#    'Renton': 150.8,
#    'Evanston': 150.9195,
#    'Champaign': 151.96,
#    'Chesapeake': 153.28,
#    'Highland Park': 153.584,
#    'Olympia': 155.25,
#    'Glenview': 158.376,
#    'Pleasant Grove': 158.9,
#    'Farmington': 159.99,
#    'Lebanon': 163.96,
#    'Perth Amboy': 164.545,
#    'San Angelo': 166.838,
#    'Lincoln Park': 167.292,
#    'Clifton': 168.41,
#    'Mount Vernon': 171.81,
#    'Buffalo': 177.42499999999998,
#    'Marietta': 182.67000000000002,
#    'La Mesa': 183.765,
#    'Hattiesburg': 185.57999999999998,
#    'Hampton': 186.54,
#    'Montgomery': 187.21499999999997,
#    'Chula Vista': 192.8,
#    'Santa Barbara': 193.92,
#    'Gresham': 195.136,
#    'Boise': 197.373,
#    'Texas City': 199.304,
#    'Noblesville': 199.83999999999997,
#    'Gaithersburg': 202.95999999999998,
#    'Summerville': 203.46999999999997,
#    'Passaic': 216.13299999999998,
#    'Warner Robins': 217.39999999999998,
#    'Eau Claire': 217.76999999999998,
#    'Tamarac': 224.293,
#    'Southaven': 234.36,
#    'Brownsville': 237.09600000000003,
#    'Gastonia': 240.774,
#    'Coon Rapids': 251.565,
#    'Park Ridge': 254.74400000000003,
#    'Bangor': 255.42,
#    'Dubuque': 263.96,
#    'Longmont': 266.35200000000003,
#    'Moorhead': 271.93,
#    'Manhattan': 273.96,
#    'Oak Park': 273.96,
#    'Cedar Rapids': 278.4,
#    'Mansfield': 279.43850000000003,
#    'Mount Pleasant': 281.53999999999996,
#    'Ontario': 283.92,
#    'Lake Elsinore': 283.92,
#    'Canton': 287.92,
#    'Lawton': 291.035,
#    'Holyoke': 301.96,
#    'Conway': 301.96,
#    'Dearborn': 301.96,
#    'San Gabriel': 303.25,
#    'Texarkana': 327.12,
#    'Redding': 333.576,
#    'Des Plaines': 336.91,
#    'Hesperia': 338.23875,
#    'Orland Park': 339.96000000000004,
#    'Pasco': 352.31999999999994,
#    'Normal': 366.74399999999997,
#    'Carol Stream': 382.116,
#    'Mishawaka': 388.12,
#    'Pharr': 395.402,
#    'Kenosha': 399.95,
#    'Buffalo Grove': 415.6995,
#    'Vacaville': 423.28,
#    'El Cajon': 432.808,
#    'Whittier': 444.76800000000003,
#    'Edmond': 479.77500000000003,
#    'Murrieta': 484.65000000000003,
#    'Missoula': 487.98400000000004,
#    'Rio Rancho': 557.096,
#    'Twin Falls': 574.4029999999999,
#    'Saint Cloud': 603.92,
#    'Richardson': 644.2320000000002,
#    'Norman': 675.6650000000001,
#    'Saint Peters': 697.16,
#    'Beverly': 704.25,
#    'Torrance': 742.736,
#    'Kissimmee': 751.984,
#    'Lehi': 758.363,
#    'Appleton': 835.655,
#    'Bellingham': 1099.5,
#    'Independence': 1208.685,
#    'Burbank': 1279.968,
#    'Cheyenne': 1603.1360000000002,
#    'Jamestown': 2354.395}},
#  {'State': {'North Dakota': 25.9,
#    'Iowa': 33.465,
#    'Nebraska': 34.2,
#    'South Dakota': 34.25,
#    'District of Columbia': 35.8,
#    'Texas': 36.28800000000001,
#    'Illinois': 36.568,
#    'Florida': 41.47200000000001,
#    'Pennsylvania': 41.47200000000001,
#    'Tennessee': 42.047999999999995,
#    'Ohio': 44.376,
#    'North Carolina': 45.216,
#    'New Mexico': 45.36,
#    'Oregon': 46.596000000000004,
#    'Connecticut': 50.0,
#    'Minnesota': 50.4,
#    'Colorado': 51.016000000000005,
#    'Arkansas': 54.42,
#    'Missouri': 57.685,
#    'New York': 60.045,
#    'Utah': 60.12,
#    'California': 61.019999999999996,
#    'Arizona': 61.512,
#    'Massachusetts': 63.2,
#    'Kansas': 63.980000000000004,
#    'Montana': 63.980000000000004,
#    'Louisiana': 64.14,
#    'Virginia': 65.25,
#    'Washington': 65.94,
#    'New Jersey': 66.73,
#    'Delaware': 67.005,
#    'New Hampshire': 68.62,
#    'South Carolina': 69.97,
#    'Indiana': 70.08,
#    'Georgia': 70.95500000000001,
#    'Alabama': 70.98,
#    'Rhode Island': 71.2,
#    'Kentucky': 76.3,
#    'Mississippi': 77.56,
#    'Nevada': 79.14,
#    'Oklahoma': 79.55,
#    'Michigan': 85.52,
#    'Maryland': 89.82000000000001,
#    'Idaho': 89.97,
#    'Wisconsin': 93.85999999999999,
#    'Maine': 105.72,
#    'Vermont': 205.03,
#    'West Virginia': 265.12,
#    'Wyoming': 1603.1360000000002}},
#  {'Sub-Category': {'Fasteners': 10.584,
#    'Labels': 14.940000000000001,
#    'Art': 15.504000000000001,
#    'Binders': 18.56,
#    'Paper': 26.720000000000002,
#    'Supplies': 27.93,
#    'Envelopes': 29.046,
#    'Furnishings': 41.96,
#    'Appliances': 82.69,
#    'Accessories': 100.0,
#    'Storage': 113.92800000000001,
#    'Phones': 209.96999999999997,
#    'Bookcases': 306.82025,
#    'Chairs': 362.13599999999997,
#    'Tables': 447.84,
#    'Machines': 599.9850000000001,
#    'Copiers': 1099.98}},
#  {'Product Name': {'Computer Printout Index Tabs': 1.5119999999999998,
#    'Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac': 1.6239999999999994,
#    'Avery Hidden Tab Dividers for Binding Systems': 1.7879999999999996,
#    'Insertable Tab Indexes For Data Binders': 1.9080000000000004,
#    'Avery Triangle Shaped Sheet Lifters, Black, 2/Pack': 2.2140000000000004,
#    'Maxell 4.7GB DVD+R 5/Pack': 2.3760000000000003,
#    'OIC Binder Clips, Mini, 1/4" Capacity, Black': 2.48,
#    'Wilson Jones Suede Grain Vinyl Binders': 2.78,
#    'Hoover Replacement Belt for Commercial Guardsman Heavy-Duty Upright Vacuum': 2.886,
#    'Maxell 4.7GB DVD-R 5/Pack': 2.9699999999999998,
#    'Acco Economy Flexible Poly Round Ring Binder': 3.132,
#    'Storex Flexible Poly Binders with Double Pockets': 3.1680000000000006,
#    'Wilson Jones Easy Flow II Sheet Lifters': 3.42,
#    'Acco Suede Grain Vinyl Round Ring Binder': 3.4749999999999996,
#    'Binder Clips by OIC': 3.5519999999999996,
#    'Avery Reinforcements for Hole-Punch Pages': 3.5639999999999996,
#    'Assorted Color Push Pins': 3.62,
#    'OIC #2 Pencils, Medium Soft': 3.76,
#    'Acco Hanging Data Binders': 3.81,
#    'Nontoxic Chalk': 3.872,
#    'Avery Hi-Liter Comfort Grip Fluorescent Highlighter, Yellow Ink': 3.9,
#    'UniKeep View Case Binders': 3.912,
#    'Brites Rubber Bands, 1 1/2 oz. Box': 3.96,
#    'Stockwell Gold Paper Clips': 4.048,
#    'Angle-D Ring Binders': 4.102500000000001,
#    'Design Ebony Sketching Pencil': 4.17,
#    'Newell 308': 4.2,
#    'Newell 310': 4.224,
#    'Colored Push Pins': 4.344,
#    'Peel & Stick Add-On Corner Pockets': 4.536000000000001,
#    'GE General Purpose, Extra Long Life, Showcase & Floodlight Incandescent Bulbs': 4.656000000000001,
#    'Pressboard Covers with Storage Hooks, 9 1/2" x 11", Light Blue': 4.6645,
#    'Round Ring Binders': 4.680000000000001,
#    'Prang Dustless Chalk Sticks': 4.704,
#    'Maxell CD-R Discs': 4.728,
#    'Kleencut Forged Office Shears by Acme United Corporation': 4.784000000000001,
#    'Faber Castell Col-Erase Pencils': 4.89,
#    'Wilson Jones Custom Binder Spines & Labels': 4.896000000000001,
#    'Poly String Tie Envelopes': 4.896000000000001,
#    'Newell 322': 4.914,
#    'BIC Brite Liner Grip Highlighters': 4.92,
#    'Letter Slitter': 5.04,
#    'Bagged Rubber Bands': 5.04,
#    'Avery 502': 5.04,
#    'Avery 488': 5.04,
#    'Storex DuraTech Recycled Plastic Frosted Binders': 5.087999999999999,
#    'Self-Adhesive Ring Binder Labels': 5.104000000000001,
#    'Binney & Smith inkTank Desk Highlighter, Chisel Tip, Yellow, 12/Box': 5.16,
#    'Accohide Poly Flexible Ring Binders': 5.236000000000001,
#    'Newell 337': 5.248,
#    'Storex Dura Pro Binders': 5.346000000000002,
#    'Newell 307': 5.46,
#    'OIC Thumb-Tacks': 5.4719999999999995,
#    'Binney & Smith inkTank Erasable Pocket Highlighter, Chisel Tip, Yellow': 5.4719999999999995,
#    'Avery Durable Binders': 5.472,
#    'Avery 511': 5.5440000000000005,
#    'Newell 333': 5.56,
#    'Newell 326': 5.632,
#    'DIXON Oriole Pencils': 5.676,
#    'SANFORD Liquid Accent Tank-Style Highlighters': 5.68,
#    'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Executive Red': 5.715000000000002,
#    'Newell 346': 5.76,
#    'Avery 5': 5.76,
#    'Avery 482': 5.78,
#    'Alliance Big Bands Rubber Bands, 12/Pack': 5.9399999999999995,
#    'Avery 510': 6.0,
#    'Binney & Smith inkTank Erasable Desk Highlighter, Chisel Tip, Yellow, 12/Box': 6.048,
#    'Stackable Trays': 6.16,
#    'Smead Alpha-Z Color-Coded Second Alphabetical Labels and Starter Set': 6.16,
#    'Zipper Ring Binder Pockets': 6.24,
#    '12 Colored Short Pencils': 6.24,
#    'Avery 479': 6.264,
#    'Avery Durable Slant Ring Binders With Label Holder': 6.27,
#    'Avery 520': 6.3,
#    'Newell 3-Hole Punched Plastic Slotted Magazine Holders for Binders': 6.3980000000000015,
#    'Xerox 20': 6.48,
#    'Permanent Self-Adhesive File Folder Labels for Typewriters by Universal': 6.525,
#    'Avery Round Ring Poly Binders': 6.532,
#    'Ampad Evidence Wirebond Steno Books, 6" x 9"': 6.540000000000001,
#    '3-ring staple pack': 6.58,
#    'Sanford Uni-Blazer View Highlighters, Chisel Tip, Yellow': 6.6000000000000005,
#    'Avery Binder Labels': 6.613,
#    'Newell 311': 6.63,
#    'Newell 327': 6.63,
#    'Avery 501': 6.6419999999999995,
#    'Prang Drawing Pencil Set': 6.671999999999999,
#    'Eldon Spacemaker Box, Quick-Snap Lid, Clear': 6.68,
#    'Cardinal Poly Pocket Divider Pockets for Ring Binders': 6.720000000000001,
#    'Alliance Rubber Bands': 6.720000000000001,
#    'Presstex Flexible Ring Binders': 6.824999999999999,
#    'Economy Binders': 6.864000000000001,
#    'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Light Blue': 6.873999999999999,
#    'Avery 474': 6.911999999999999,
#    'Acco Banker\'s Clasps, 5 3/4"-Long': 6.911999999999999,
#    'Sannysis Cute Owl Design Soft Skin Case Cover for Samsung Galaxy S4': 6.93,
#    'Newell 344': 6.949999999999999,
#    'Eldon Regeneration Recycled Desk Accessories, Smoke': 6.96,
#    'Advantus Push Pins': 6.976000000000001,
#    'Acme Serrated Blade Letter Opener': 6.996,
#    'Ideal Clamps': 7.034999999999999,
#    'Regeneration Desk Collection': 7.04,
#    'Avery 494': 7.047000000000001,
#    'Avery 509': 7.047000000000001,
#    'Grip Seal Envelopes': 7.072,
#    'Premium Writing Pencils, Soft, #2 by Central Association for the Blind': 7.151999999999999,
#    'Avery Poly Binder Pockets': 7.16,
#    'Cardinal Hold-It CD Pocket': 7.1819999999999995,
#    'Avery Non-Stick Binders': 7.184000000000001,
#    'Recycled Pressboard Report Cover with Reinforced Top Hinge': 7.2675,
#    'Acme Value Line Scissors': 7.3,
#    'Staple remover': 7.36,
#    'Color-Coded Legal Exhibit Labels': 7.365,
#    'Avery 487': 7.38,
#    'Longer-Life Soft White Bulbs': 7.392000000000001,
#    'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 9 1/2" X 11"': 7.532,
#    'Wirebound Voice Message Log Book': 7.616,
#    'Insertable Tab Post Binder Dividers': 7.619,
#    'Avery Heavy-Duty EZD View Binder with Locking Rings': 7.656,
#    'Pencil and Crayon Sharpener': 7.665,
#    'Eldon Wave Desk Accessories': 7.694,
#    'Avery Hi-Liter Pen Style Six-Color Fluorescent Set': 7.7,
#    'Tuff Stuff Recycled Round Ring Binders': 7.712000000000001,
#    'Quartet Alpha White Chalk, 12/Pack': 7.734999999999999,
#    'Revere Boxed Rubber Bands by Revere': 7.749,
#    'Acme Kleen Earth Office Shears': 7.76,
#    'GBC Instant Report Kit': 7.764000000000001,
#    'Newell 32': 7.776,
#    'Commercial WindTunnel Clean Air Upright Vacuum, Replacement Belts, Filtration Bags': 7.78,
#    'Newell 348': 7.872,
#    'Translucent Push Pins by OIC': 7.92,
#    'Ibico Presentation Index for Binding Systems': 7.96,
#    'Xerox 1989': 7.968000000000001,
#    'Economy #2 Pencils': 7.98,
#    'Super Bands, 12/Pack': 7.998000000000001,
#    'Sanford Pocket Accent Highlighters': 8.0,
#    'Acco Pressboard Covers with Storage Hooks, 14 7/8" x 11", Dark Blue': 8.001000000000001,
#    'Avery Fluorescent Highlighter Four-Color Set': 8.016,
#    '4009 Highlighters': 8.040000000000001,
#    'Binney & Smith Crayola Metallic Crayons, 16-Color Pack': 8.088000000000001,
#    'American Pencil': 8.155000000000001,
#    'Rogers Handheld Barrel Pencil Sharpener': 8.22,
#    'Wilson Jones Impact Binders': 8.288,
#    'SlimView Poly Binder, 3/8"': 8.288,
#    'Newell 339': 8.34,
#    'Newell 323': 8.4,
#    'Black Avery Memo-Size 3-Ring Binder, 5 1/2" x 8 1/2"': 8.440999999999999,
#    'Xerox 1972': 8.448,
#    'Xerox 1900': 8.56,
#    'Xerox 1953': 8.560000000000002,
#    'Binder Posts': 8.610000000000001,
#    'Newell 335': 8.64,
#    'Avery File Folder Labels': 8.64,
#    '3M Organizer Strips': 8.64,
#    'Staple-on labels': 8.67,
#    'Newell 317': 8.82,
#    'Newell 343': 8.82,
#    'GBC Standard Plastic Binding Systems Combs': 8.849999999999998,
#    'Newell 350': 8.856,
#    'Colored Envelopes': 8.856,
#    '"While you Were Out" Message Book, One Form per Page': 8.904,
#    'Eldon Pizzaz Desk Accessories': 8.92,
#    'Plastic Stacking Crates & Casters': 8.928,
#    'Dixon Ticonderoga Pencils': 8.94,
#    'Xerox 1949': 8.964,
#    'Smead Alpha-Z Color-Coded Name Labels First Letter Starter Set': 9.0,
#    'Hoover Commercial Lightweight Upright Vacuum': 9.048,
#    '#10 Gummed Flap White Envelopes, 100/Box': 9.086,
#    'Manco Dry-Lighter Erasable Highlighter': 9.120000000000001,
#    'Loose Memo Sheets': 9.125,
#    'Acco Pressboard Covers with Storage Hooks, 9 1/2" x 11", Executive Red': 9.144,
#    'Unpadded Memo Slips': 9.154,
#    'Acme Kleencut Forged Steel Scissors': 9.184000000000001,
#    'Dixon Ticonderoga Maple Cedar Pencil, #2': 9.209999999999999,
#    'Acco Hot Clips Clips to Go': 9.212,
#    'Avery 484': 9.216,
#    'Avery Binding System Hidden Tab Executive Style Index Sets': 9.232,
#    'Avery 498': 9.248000000000001,
#    'Binney & Smith Crayola Metallic Colored Pencils, 8-Color Set': 9.26,
#    'Fellowes Black Plastic Comb Bindings': 9.296,
#    'Letter or Legal Size Expandable Poly String Tie Envelopes': 9.31,
#    'Hoover Replacement Belts For Soft Guard & Commercial Ltweight Upright Vacs, 2/Pk': 9.48,
#    'Avery Durable Slant Ring Binders, No Labels': 9.552000000000001,
#    'PNY Rapid USB Car Charger - Black': 9.588,
#    'Stockwell Push Pins': 9.592000000000002,
#    'Acrylic Self-Standing Desk Frames': 9.612,
#    'Wilson Jones Turn Tabs Binder Tool for Ring Binders': 9.64,
#    'Adams Telephone Message Books, 5 1/4” x 11”': 9.664000000000001,
#    'Acco Side-Punched Conventional Columnar Pads': 9.716000000000001,
#    'Prestige Round Ring Binders': 9.728000000000002,
#    "GBC Standard Plastic Binding Systems' Combs": 9.734000000000002,
#    'Avery 518': 9.765,
#    'Newell 35': 9.84,
#    'Newell 313': 9.84,
#    'Newell 342': 9.84,
#    'Nu-Dell EZ-Mount Plastic Wall Frames': 9.850000000000001,
#    'Universal Recycled Hanging Pressboard Report Binders, Letter Size': 9.872,
#    'Sterling Rubber Bands by Alliance': 9.891,
#    'ACCOHIDE 3-Ring Binder, Blue, 1"': 9.912,
#    'Hammermill CopyPlus Copy Paper (20Lb. and 84 Bright)': 9.96,
#    'Stacking Trays by OIC': 9.96,
#    'Ampad Poly Cover Wirebound Steno Book, 6" x 9" Assorted Colors, Gregg Ruled': 9.988,
#    'Xerox 1986': 10.02,
#    'Eldon 100 Class Desk Accessories': 10.11,
#    'Wilson Jones Standard D-Ring Binders': 10.120000000000001,
#    'Avery Hi-Liter Fluorescent Desk Style Markers': 10.139999999999999,
#    'Crayola Anti Dust Chalk, 12/Pack': 10.192000000000002,
#    'Tops Wirebound Message Log Books': 10.199000000000002,
#    'Acco Expandable Hanging Binders': 10.208,
#    'Xerox 1971': 10.272000000000002,
#    'Newell 320': 10.272000000000002,
#    'Avery 05222 Permanent Self-Adhesive File Folder Labels for Typewriters, on Rolls, White, 250/Roll': 10.325,
#    'GBC Plasticlear Binding Covers': 10.332000000000003,
#    'Avery 49': 10.367999999999999,
#    'Xerox 206': 10.368000000000002,
#    'Xerox 224': 10.368000000000002,
#    'Newell 351': 10.496,
#    'Important Message Pads, 50 4-1/4 x 5-1/2 Forms per Pad': 10.5,
#    'Sanford EarthWrite Recycled Pencils, Medium Soft, #2': 10.5,
#    'Magna Visual Magnetic Picture Hangers': 10.604000000000001,
#    'Acco Clips to Go Binder Clips, 24 Clips in Two Sizes': 10.649999999999999,
#    'Pressboard Data Binders by Wilson Jones': 10.68,
#    'Turquoise Lead Holder with Pocket Clip': 10.72,
#    'Stacking Tray, Side-Loading, Legal, Smoke': 10.752000000000002,
#    'Acco PRESSTEX Data Binder with Storage Hooks, Light Blue, 9 1/2" X 11"': 10.76,
#    'OIC Bulk Pack Metal Binder Clips': 10.819,
#    'Pressboard Hanging Data Binders for Unburst Sheets': 10.824,
#    'Advantus T-Pin Paper Clips': 10.824,
#    'Convenience Packs of Business Envelopes': 10.86,
#    'Avery Self-Adhesive Photo Pockets for Polaroid Photos': 10.896,
#    'Avery Durable Plastic 1" Binders': 10.896,
#    'Disposable Triple-Filter Dust Bags': 10.925,
#    'Acme Design Line 8" Stainless Steel Bent Scissors w/Champagne Handles, 3-1/8" Cut': 10.944,
#    'SpineVue Locking Slant-D Ring Binders by Cardinal': 10.968000000000002,
#    'Avery 517': 11.07,
#    'Avery 52': 11.07,
#    'Wilson Jones 1" Hanging DublLock Ring Binders': 11.088000000000003,
#    'Newell 318': 11.12,
#    'QVS USB Car Charger 2-Port 2.1Amp for iPod/iPhone/iPad/iPad 2/iPad 3': 11.120000000000001,
#    'Newell 314': 11.16,
#    'Avery Printable Repositionable Plastic Tabs': 11.18,
#    'Spiral Phone Message Books with Labels by Adams': 11.200000000000001,
#    'Acco Translucent Poly Ring Binders': 11.232,
#    'GBC ProClick Spines for 32-Hole Punch': 11.277000000000001,
#    'While You Were Out Pads, 50 per Pad, 4 x 5 1/4, Green Cycle': 11.352000000000002,
#    'Adams Write n\' Stick Phone Message Book, 11" X 5 1/4", 200 Messages': 11.36,
#    'Cush Cases Heavy Duty Rugged Cover Case for Samsung Galaxy S5 - Purple': 11.385000000000002,
#    'Cardinal HOLDit! Binder Insert Strips,Extra Strips': 11.393999999999998,
#    'Avery 492': 11.52,
#    'Sanford Colorific Colored Pencils, 12/Box': 11.52,
#    'Xerox 199': 11.556000000000001,
#    'Xerox 196': 11.56,
#    'Xerox 1899': 11.56,
#    'Xerox 1969': 11.56,
#    'Xerox 1950': 11.56,
#    'Xerox 1966': 11.664000000000001,
#    'Mead 1st Gear 2" Zipper Binder, Asst. Colors': 11.673000000000002,
#    'Quartet Omega Colored Chalk, 12/Pack': 11.68,
#    'OIC Stacking Trays': 11.690000000000001,
#    'Newell 338': 11.76,
#    'Newell 332': 11.76,
#    'Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 300/Messages': 11.76,
#    'Avery 508': 11.784,
#    'Redi-Strip #10 Envelopes, 4 1/8 x 9 1/2': 11.8,
#    'Avery Durable Slant Ring Binders': 11.880000000000003,
#    'Ampad Gold Fibre Wirebound Steno Books, 6" x 9", Gregg Ruled': 11.907,
#    'Woodgrain Magazine Files by Perma': 11.92,
#    'Serrated Blade or Curved Handle Hand Letter Openers': 11.932000000000002,
#    'Cardinal Holdit Business Card Pockets': 11.952000000000002,
#    'Xerox 1922': 11.952000000000002,
#    'Xerox 1974': 11.96,
#    'GBC Personal VeloBind Strips': 11.979999999999997,
#    'Avery 497': 12.012,
#    'Avery 507': 12.096,
#    'Imation\xa0USB 2.0 Swivel\xa0Flash Drive\xa0USB\xa0flash drive\xa0- 4 GB - Pink': 12.12,
#    'Newell 329': 12.136,
#    'Avery Durable Poly Binders': 12.166,
#    'RSVP Cards & Envelopes, Blank White, 8-1/2" X 11", 24 Cards/25 Envelopes/Set': 12.192,
#    'Avery 496': 12.375,
#    'Newell Chalk Holder': 12.39,
#    'ACCOHIDE Binder by Acco': 12.39,
#    'Eldon Image Series Black Desk Accessories': 12.419999999999998,
#    'BIC Brite Liner Highlighters': 12.419999999999998,
#    'Xerox 1952': 12.450000000000001,
#    'Barrel Sharpener': 12.495,
#    'XtraLife ClearVue Slant-D Ring Binders by Cardinal': 12.544,
#    'Blackstonian Pencils': 12.549,
#    'Sterilite Show Offs Storage Containers': 12.672,
#    'Master Caster Door Stop, Gray': 12.7,
#    'Pressboard Data Binder, Crimson, 12" X 8 1/2"': 12.816,
#    'Xerox 1927': 12.84,
#    'Newell 341': 12.84,
#    'Xerox 1962': 12.84,
#    'Xerox 1975': 12.96,
#    'Xerox 213': 12.96,
#    'Xerox 1984': 12.96,
#    'Xerox 1999': 12.96,
#    'Newell 340': 12.96,
#    'Xerox 218': 12.96,
#    'Xerox 227': 12.96,
#    'Xerox 1985': 12.960000000000003,
#    'SanDisk Cruzer 4 GB USB Flash Drive': 12.98,
#    'Sanitaire Vibra Groomer IR Commercial Upright Vacuum, Replacement Belts': 13.0,
#    'Avery Hi-Liter GlideStik Fluorescent Highlighter, Yellow Ink': 13.04,
#    'Rubber Band Ball': 13.09,
#    'Crayola Colored Pencils': 13.12,
#    'Sanford Colorific Eraseable Coloring Pencils, 12 Count': 13.120000000000001,
#    'Newell 349': 13.120000000000001,
#    'Advantus Panel Wall Acrylic Frame': 13.128,
#    'Xerox 1965': 13.156000000000002,
#    'Wilson Jones data.warehouse D-Ring Binders with DublLock': 13.168000000000001,
#    'Avery 491': 13.216000000000001,
#    'G.E. Longer-Life Indoor Recessed Floodlight Bulbs': 13.28,
#    'Self-Adhesive Address Labels for Typewriters with Dispenser Box': 13.284,
#    '3M Hangers With Command Adhesive': 13.32,
#    'DIXON Ticonderoga Erasable Checking Pencils': 13.392000000000001,
#    'GBC VeloBinder Strips': 13.440000000000001,
#    'Avoid Verbal Orders Carbonless Minifold Book': 13.52,
#    'Memorex Mini Travel Drive 4 GB USB 2.0 Flash Drive': 13.616,
#    'Dixon Prang Watercolor Pencils, 10-Color Set with Brush': 13.632,
#    'Staples': 13.722000000000001,
#    'Advantus Map Pennant Flags and Round Head Tacks': 13.825000000000001,
#    'Angle-D Binders with Locking Rings, Label Holders': 13.869999999999997,
#    'Xerox 1924': 13.872,
#    'Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl': 13.904,
#    'Wilson Jones Clip & Carry Folder Binder Tool for Ring Binders, Clear': 13.919999999999998,
#    'Wilson Jones “Snap” Scratch Pad Binder Tool for Ring Binders': 13.919999999999998,
#    'Xerox 1897': 13.944,
#    'G.E. Halogen Desk Lamp Bulbs': 13.96,
#    'Dax Clear Box Frame': 13.968,
#    'Belkin 7-Outlet SurgeMaster Home Series': 13.97,
#    'Avery Framed View Binder, EZD Ring (Locking), Navy, 1 1/2"': 13.972000000000001,
#    'Hunt BOSTON Vista Battery-Operated Pencil Sharpener, Black': 13.992,
#    'Acco 3-Hole Punch': 14.016,
#    'Plymouth Boxed Rubber Bands by Plymouth': 14.129999999999999,
#    'Akro Stacking Bins': 14.202,
#    'Xerox 1993': 14.256000000000002,
#    'Xerox 210': 14.256000000000002,
#    'Xerox 1957': 14.256000000000002,
#    'Avery Premier Heavy-Duty Binder with Round Locking Rings': 14.28,
#    'Avery Hanging File Binders': 14.352000000000002,
#    'Nu-Dell Float Frame 11 x 14 1/2': 14.368000000000002,
#    'Southworth Parchment Paper & Envelopes': 14.388000000000002,
#    'Avery 514': 14.399999999999999,
#    'Avery 512': 14.450000000000001,
#    'Avery 476': 14.455,
#    'Eldon Regeneration Recycled Desk Accessories, Black': 14.52,
#    'Master Caster Door Stop, Large Brown': 14.56,
#    'Master Caster Door Stop, Large Neon Orange': 14.560000000000002,
#    'Wilson Jones Active Use Binders': 14.560000000000002,
#    'Rediform Voice Mail Log Books': 14.602,
#    'Avery 486': 14.62,
#    'Self-Adhesive Address Labels for Typewriters by Universal': 14.62,
#    'Eldon Image Series Desk Accessories, Burgundy': 14.629999999999999,
#    'C-Line Cubicle Keepers Polyproplyene Holder With Velcro Backings': 14.663000000000002,
#    'Xerox 1959': 14.696,
#    'Prang Colored Pencils': 14.7,
#    'Ultra Door Push Plate': 14.73,
#    'Eldon Expressions Wood Desk Accessories, Oak': 14.76,
#    'GBC Plastic Binding Combs': 14.76,
#    'SKILCRAFT Telephone Shoulder Rest, 2" x 6.5" x 2.5", Black': 14.78,
#    'Eldon 300 Class Desk Accessories, Black': 14.85,
#    'Eberhard Faber 3 1/2" Golf Pencils': 14.88,
#    'DAX Value U-Channel Document Frames, Easel Back': 14.91,
#    'Avery 513': 14.940000000000001,
#    'Xerox 190': 14.940000000000001,
#    'Xerox 1970': 14.940000000000001,
#    'Avery 499': 14.940000000000001,
#    'Avery 483': 14.940000000000001,
#    'Newell 330': 14.950000000000001,
#    'Xerox 1983': 14.950000000000001,
#    'Avery Hole Reinforcements': 14.952000000000002,
#    'Boston 1900 Electric Pencil Sharpener': 14.98,
#    'Hammermill Color Copier Paper (28Lb. and 96 Bright)': 14.985,
#    'Flexible Leather- Look Classic Collection Ring Binder': 15.152,
#    'Avery 493': 15.221,
#    'TOPS Voice Message Log Book, Flash Format': 15.232,
#    'Heavy-Duty E-Z-D Binders': 15.274000000000001,
#    'Security-Tint Envelopes': 15.28,
#    'Wilson Jones Four-Pocket Poly Binders': 15.369000000000002,
#    'Colorific Watercolor Pencils': 15.48,
#    'Array Memo Cubes': 15.54,
#    'Xerox 2': 15.552000000000003,
#    'Universal Ultra Bright White Copier/Laser Paper, 8 1/2" x 11", Ream': 15.552000000000003,
#    'Xerox 1967': 15.552000000000003,
#    'Xerox 21': 15.552000000000003,
#    'Eureka Recycled Copy Paper 8 1/2" x 11", Ream': 15.552000000000003,
#    'Xerox 200': 15.552000000000003,
#    'Southworth 25% Cotton Granite Paper & Envelopes': 15.696000000000002,
#    'Adams "While You Were Out" Message Pads': 15.700000000000001,
#    'Self-Adhesive Removable Labels': 15.75,
#    '#6 3/4 Gummed Flap White Envelopes': 15.840000000000002,
#    'Telephone Message Books with Fax/Mobile Section, 5 1/2" x 3 3/16"': 15.874999999999998,
#    'Acme Rosewood Handle Letter Opener': 15.88,
#    'Fluorescent Highlighters by Dixon': 15.920000000000002,
#    'Xerox 198': 15.936000000000002,
#    'Xerox 1921': 15.984000000000002,
#    'EcoTones Memo Sheets': 16.0,
#    'Wirebound Message Books, 5-1/2 x 4 Forms, 2 or 4 Forms per Page': 16.056,
#    'Fellowes Twister Kit, Gray/Clear, 3/pkg': 16.08,
#    'Hoover Portapower Portable Vacuum': 16.128,
#    'Great White Multi-Use Recycled Paper (20Lb. and 84 Bright)': 16.146,
#    'Memo Book, 100 Message Capacity, 5 3/8” x 11”': 16.176000000000002,
#    'Xerox 1958': 16.200000000000003,
#    'Fashion Color Clasp Envelopes': 16.23,
#    'Wilson Jones Hanging Recycled Pressboard Data Binders': 16.324,
#    'Newell 31': 16.520000000000003,
#    '#10 Self-Seal White Envelopes': 16.634999999999998,
#    'Acme Elite Stainless Steel Scissors': 16.68,
#    'Wirebound Message Books, Four 2 3/4 x 5 Forms per Page, 200 Sets per Book': 16.695,
#    'Xerox 1977': 16.7,
#    'Acme Stainless Steel Office Snips': 16.721,
#    'Newell 33': 16.740000000000002,
#    'AmazonBasics 3-Button USB Wired Mouse': 16.776000000000003,
#    'SmartStand Mobile Device Holder, Assorted Colors': 16.776000000000003,
#    '#10- 4 1/8" x 9 1/2" Security-Tint Envelopes': 16.808,
#    'Clear Mylar Reinforcing Strips': 16.821000000000005,
#    'Avery 480': 16.875,
#    'Xerox 1901': 16.896,
#    'Xerox 1981': 16.896,
#    'Avery 495': 17.009999999999998,
#    'Advantus SlideClip Paper Clips': 17.05,
#    'Dana Swing-Arm Lamps': 17.088,
#    'Newell 331': 17.115,
#    'Newell 336': 17.12,
#    'Newell 347': 17.12,
#    'Xerox 1980': 17.12,
#    'GBC Standard Recycled Report Covers, Clear Plastic Sheets': 17.248,
#    'Avery Heavy-Duty EZD  Binder With Locking Rings': 17.298000000000002,
#    'Wilson Jones International Size A4 Ring Binders': 17.3,
#    'DAX Cubicle Frames - 8x10': 17.31,
#    'Cardinal Slant-D Ring Binders': 17.38,
#    'Wirebound Four 2-3/4 x 5 Forms per Page, 400 Sets per Book': 17.415,
#    'Peel & Seel Envelopes': 17.46,
#    'Wilson Jones Leather-Like Binders with DublLock Round Rings': 17.46,
#    'Black Print Carbonless 8 1/2" x 8 1/4" Rapid Memo Book': 17.472,
#    'Eureka Sanitaire  Multi-Pro Heavy-Duty Upright, Disposable Bags': 17.48,
#    'Xerox 220': 17.496000000000002,
#    'Xerox 1994': 17.496000000000002,
#    'Xerox 1995': 17.496000000000002,
#    'Xerox 217': 17.496000000000002,
#    'Eldon Imàge Series Desk Accessories, Clear': 17.496000000000002,
#    'Newell 312': 17.52,
#    'Shocksock Galaxy S4 Armband': 17.52,
#    'Things To Do Today Pad': 17.61,
#    'GBC Instant Index System for Binding Systems': 17.76,
#    'Wilson Jones DublLock D-Ring Binders': 17.8875,
#    'OIC Colored Binder Clips, Assorted Sizes': 17.9,
#    'OIC Binder Clips': 17.9,
#    'Ampad #10 Peel & Seel Holiday Envelopes': 17.92,
#    'Stride Job 150 Highlighters, Chisel Tip, Assorted Colors': 17.94,
#    'Wausau Papers Astrobrights Colored Envelopes': 17.94,
#    'Xerox 1992': 17.94,
#    'Avery Non-Stick Heavy Duty View Round Locking Ring Binders': 17.94,
#    'Newell 315': 17.94,
#    'Wirebound Message Forms, Four 2 3/4 x 5 Forms per Page, Pink Paper': 17.974,
#    'Advantus Plastic Paper Clips': 18.0,
#    'Telephone Message Books with Fax/Mobile Section, 4 1/4" x 6"': 18.0,
#    'Xerox 195': 18.036,
#    'Acco Recycled 2" Capacity Laser Printer Hanging Data Binders': 18.0625,
#    'Contemporary Borderless Frame': 18.081,
#    'Avery Hi-Liter Smear-Safe Highlighters': 18.104,
#    'Xerox 1976': 18.144000000000005,
#    'Fiskars Spring-Action Scissors': 18.174,
#    'Bravo II Megaboss 12-Amp Hard Body Upright, Replacement Belts, 2 Belts per Pack': 18.2,
#    'Avery 3 1/2" Diskette Storage Pages, 10/Pack': 18.27,
#    'Avery 519': 18.275,
#    'Strathmore Photo Frame Cards': 18.275,
#    'Avery 516': 18.275,
#    'Xerox 1990': 18.48,
#    'Xerox 1903': 18.538000000000004,
#    'Durable Pressboard Binders': 18.62,
#    'Wilson Jones 14 Line Acrylic Coated Pressboard Data Binders': 18.689999999999998,
#    'Newell 321': 18.695999999999998,
#    'Eldon 200 Class Desk Accessories': 18.84,
#    'Col-Erase Pencils with Erasers': 18.848000000000003,
#    'Zebra Zazzle Fluorescent Highlighters': 18.848000000000003,
#    'Permanent Self-Adhesive File Folder Labels for Typewriters, 1 1/8 x 3 1/2, White': 18.9,
#    'Avery 51': 18.9,
#    'Avery 48': 18.9,
#    'DAX Two-Tone Rosewood/Black Document Frame, Desktop, 5 x 7': 18.96,
#    'Kingston Digital DataTraveler 8GB USB 2.0': 19.040000000000003,
#    'Acco 6 Outlet Guardian Basic Surge Suppressor': 19.136,
#    'Wirebound Service Call Books, 5 1/2" x 4"': 19.36,
#    'Xerox 2000': 19.44,
#    'Xerox 201': 19.44,
#    'Xerox 202': 19.44,
#    'Xerox 225': 19.44,
#    'Xerox 223': 19.44,
#    'Xerox 212': 19.44,
#    'Xerox 222': 19.44,
#    'Xerox 214': 19.44,
#    'Xerox 22': 19.44,
#    'BIC Brite Liner Grip Highlighters, Assorted, 5/Pack': 19.504,
#    'Acco Glide Clips': 19.6,
#    'Avery 478': 19.64,
#    'Lumber Crayons': 19.7,
#    'C-Line Magnetic Cubicle Keepers, Clear Polypropylene': 19.76,
#    'Newell 325': 19.824,
#    '4009 Highlighters by Sanford': 19.9,
#    'Rediform S.O.S. Phone Message Books': 19.92,
#    'Square Credit Card Reader': 19.98,
#    'Xerox 1923': 20.04,
#    'C-Line Peel & Stick Add-On Filing Pockets, 8-3/4 x 5-1/8, 10/Pack': 20.0655,
#    'Xerox 1996': 20.088,
#    'Xerox 1997': 20.088,
#    'Xerox 207': 20.088,
#    'Hoover Commercial Soft Guard Upright Vacuum And Disposable Filtration Bags': 20.201999999999998,
#    'Xerox 1978': 20.230000000000004,
#    'Ibico Plastic and Wire Spiral Binding Combs': 20.232000000000003,
#    'Master Caster Door Stop, Brown': 20.32,
#    'Avery White Multi-Purpose Labels': 20.418000000000003,
#    'Wirebound Message Books, Two 4 1/4" x 5" Forms per Page': 20.547000000000004,
#    'Cardinal EasyOpen D-Ring Binders': 20.565000000000005,
#    'Acme Office Executive Series Stainless Steel Trimmers': 20.568,
#    'Xerox 4200 Series MultiUse Premium Copy Paper (20Lb. and 84 Bright)': 20.592,
#    'Avery 506': 20.65,
#    'Imation\xa030456 USB\xa0Flash Drive\xa08GB': 20.700000000000003,
#    'Xerox 230': 20.736000000000004,
#    'Xerox 221': 20.736000000000004,
#    'Xerox 1946': 20.736000000000004,
#    'BIC Brite Liner Highlighters, Chisel Tip': 20.736000000000004,
#    'Xerox 231': 20.736000000000004,
#    'Verbatim Slim CD and DVD Storage Cases, 50/Pack': 20.772,
#    'Cyber Acoustics AC-202b Speech Recognition Stereo Headset': 20.784000000000002,
#    'Perma STOR-ALL Hanging File Box, 13 1/8"W x 12 1/4"D x 10 1/2"H': 20.93,
#    'Adams Phone Message Book, Professional, 400 Message Capacity, 5 3/6” x 11”': 20.94,
#    'Texas Instrument TI-15 Fraction Calculator': 20.952500000000004,
#    'Staples in misc. colors': 20.96,
#    'Message Book, Phone, Wirebound Standard Line Memo, 2 3/4" X 5"': 20.96,
#    'Sabrent 4-Port USB 2.0 Hub': 21.049,
#    'Belkin Grip Candy Sheer Case / Cover for iPhone 5 and 5S': 21.072,
#    'Xerox 1954': 21.12,
#    'Wilson Jones Hanging View Binder, White, 1"': 21.299999999999997,
#    'Acco D-Ring Binder w/DublLock': 21.379999999999995,
#    'Xerox 232': 21.384000000000004,
#    'TOPS "Important Message" Pads, Canary, 4-1/4 x 5-1/2, 50 Sheets per Pad': 21.400000000000002,
#    'Avery 481': 21.560000000000002,
#    'DXL Angle-View Binders with Locking Rings by Samsill': 21.588,
#    'Strathmore Photo Mount Cards': 21.696,
#    'Wirebound Message Book, 4 per Page': 21.720000000000002,
#    'Eldon 500 Class Desk Accessories': 21.726,
#    'Pastel Pink Envelopes': 21.84,
#    '#10- 4 1/8" x 9 1/2" Recycled Envelopes': 21.85,
#    'Boston 16750 Black Compact Battery Pencil Sharpener': 21.875,
#    'Staple magnet': 21.936,
#    'Samsung Replacement EH64AVFWE Premium Headset': 22.0,
#    'Wirebound Message Books, Four 2 3/4" x 5" Forms per Page, 600 Sets per Book': 22.248,
#    'Geographics Note Cards, Blank, White, 8 1/2" x 11"': 22.38,
#    'Personal Folder Holder, Ebony': 22.42,
#    'Eldon Expressions Punched Metal & Wood Desk Accessories, Black & Cherry': 22.512000000000004,
#    'Document Clip Frames': 22.518,
#    'Xerox 203': 22.68,
#    'Xerox 215': 22.68,
#    'Xerox 228': 22.680000000000003,
#    'Xerox 219': 22.680000000000003,
#    'Adams Telephone Message Book W/Dividers/Space For Phone Numbers, 5 1/4"X8 1/2", 200/Messages': 22.72,
#    'DAX Charcoal/Nickel-Tone Document Frame, 5 x 7': 22.752000000000002,
#    'TOPS 4 x 6 Fluorescent Color Memo Sheets, 500 Sheets per Pack': 22.776000000000003,
#    'Rediform Wirebound "Phone Memo" Message Book, 11 x 5-3/4': 22.919999999999998,
#    'Avery Metallic Poly Binders': 22.92,
#    'Xerox 1987': 23.12,
#    'GBC VeloBind Cover Sets': 23.160000000000004,
#    'GBC White Gloss Covers, Plain Front': 23.168000000000003,
#    'Master Big Foot Doorstop, Beige': 23.232,
#    'Boston 16765 Mini Stand Up Battery Pencil Sharpener': 23.32,
#    'Xerox 1998': 23.328000000000007,
#    'Newell 328': 23.36,
#    'Dixon My First Ticonderoga Pencil, #2': 23.4,
#    'Newell 316': 23.472,
#    'Staple envelope': 23.472,
#    'Sanford Colorific Scented Colored Pencils, 12/Pack': 23.540000000000003,
#    'GBC Laser Imprintable Binding System Covers, Desert Sand': 23.545500000000004,
#    'Staple-based wall hangings': 23.628,
#    'Holmes Visible Mist Ultrasonic Humidifier with 2.3-Gallon Output per Day, Replacement Filter': 23.772,
#    'Verbatim 25 GB 6x Blu-ray Single Layer Recordable Disc, 1/Pack': 23.840000000000003,
#    'Acco Four Pocket Poly Ring Binder with Label Holder, Smoke, 1"': 23.840000000000003,
#    'Universal Premium White Copier/Laser Paper (20Lb. and 87 Bright)': 23.92,
#    'Xerox 1920': 23.92,
#    'Xerox 1895': 23.92,
#    'Xerox 193': 23.92,
#    'DXL Angle-View Binders with Locking Rings, Black': 23.96,
#    'GE 4 Foot Flourescent Tube, 40 Watt': 23.968000000000004,
#    'iOttie HLCRIO102 Car Mount': 23.987999999999996,
#    'Telescoping Adjustable Floor Lamp': 23.988,
#    'KeyTronic\xa0KT800P2 -\xa0Keyboard\xa0- Black': 24.032,
#    'GBC Imprintable Covers': 24.156000000000002,
#    'DAX Metal Frame, Desktop, Stepped-Edge': 24.288,
#    'Recycled Premium Regency Composition Covers': 24.448,
#    'Eldon Image Series Desk Accessories, Ebony': 24.700000000000003,
#    'GBC Wire Binding Combs': 24.816000000000003,
#    'Tenex Personal Filing Tote With Secure Closure Lid, Black/Frost': 24.816000000000003,
#    'Southworth 100% Résumé Paper, 24lb.': 24.896,
#    'Ampad Phone Message Book, Recycled, 400 Message Capacity, 5 ¾” x 11”': 24.96,
#    'Xerox 1896': 24.975,
#    'PowerGen Dual USB Car Charger': 24.975000000000005,
#    '1/4 Fold Party Design Invitations & White Envelopes, 24 8-1/2" X 11" Cards, 25 Env./Pack': 24.99,
#    'Acco Data Flex Cable Posts For Top & Bottom Load Binders, 6" Capacity': 25.031999999999996,
#    'Eldon Expressions Desk Accessory, Wood Pencil Holder, Oak': 25.090000000000003,
#    'Westinghouse Clip-On Gooseneck Lamps': 25.11,
#    'Xerox 211': 25.272000000000006,
#    'Things To Do Today Spiral Book': 25.344,
#    'Elite 5" Scissors': 25.349999999999998,
#    'Array Parchment Paper, Assorted Colors': 25.48,
#    'Acme Titanium Bonded Scissors': 25.5,
#    'Acme Preferred Stainless Steel Scissors': 25.56,
#    'Message Book, Standard Line "While You Were Out", 5 1/2" X 4", 200 Sets/Book': 25.68,
#    'Martin-Yale Premier Letter Opener': 25.76,
#    'Acco PRESSTEX Data Binder with Storage Hooks, Dark Blue, 14 7/8" X 11"': 25.824,
#    'Astroparche Fine Business Paper': 25.872,
#    'Anderson Hickey Conga Table Tops & Accessories': 25.891000000000002,
#    'Stiletto Hand Letter Openers': 25.919999999999998,
#    'Xerox 226': 25.92,
#    'Xerox 192': 25.92,
#    'Xerox 204': 25.92,
#    'Weyerhaeuser First Choice Laser/Copy Paper (20Lb. and 88 Bright)': 25.920000000000005,
#    'HP Office Recycled Paper (20Lb. and 87 Bright)': 26.01,
#    'Crate-A-Files': 26.160000000000004,
#    'Ibico Standard Transparent Covers': 26.368000000000002,
#    'Xerox 1963': 26.400000000000002,
#    'It\'s Hot Message Books with Stickers, 2 3/4" x 5"': 26.64,
#    'Xerox 1968': 26.720000000000002,
#    'Xerox 1898': 26.720000000000002,
#    'Message Book, Wirebound, Four 5 1/2" X 4" Forms/Pg., 200 Dupl. Sets/Book': 26.728,
# ...
#    'Fellowes Mighty 8 Compact Surge Protector': 62.837,
#    'Maxell 74 Minute CD-R Spindle, 50/Pack': 62.91,
#    'Howard Miller Distant Time Traveler Alarm Clock': 63.066,
#    'Nu-Dell Executive Frame': 63.2,
#    'Ultra Commercial Grade Dual Valve Door Closer': 63.824000000000005,
#    '24-Hour Round Wall Clock': 63.93600000000001,
#    'Boston 1730 StandUp Electric Pencil Sharpener': 64.14,
#    'Motorola L804': 64.386,
#    'Griffin GC17055 Auxiliary Audio Cable': 64.764,
#    'Fellowes Neat Ideas Storage Cubes': 64.96,
#    'Premium Transparent Presentation Covers by GBC': 65.03800000000001,
#    'Acco Perma 3000 Stacking Storage Drawers': 65.03800000000001,
#    'Hewlett-Packard 300S Scientific Calculator': 65.55,
#    'Contract Clock, 14", Brown': 65.94,
#    'Inter-Office Recycled Envelopes, Brown Kraft, Button-String,10" x 13" , 100/Box': 65.94,
#    'Texas Instruments TI-34 Scientific Calculator': 65.97,
#    'Fellowes Advanced Computer Series Surge Protectors': 66.225,
#    'SanDisk Ultra 32 GB MicroSDHC Class 10 Memory Card': 66.30000000000001,
#    'Sortfiler Multipurpose Personal File Organizer, Black': 66.309,
#    'OtterBox Defender Series Case - iPhone 5c': 66.564,
#    'Fellowes Presentation Covers for Comb Binding Machines': 66.93,
#    'Rogers Profile Extra Capacity Storage Tub': 66.96,
#    'iKross Bluetooth Portable Keyboard + Cell Phone Stand Holder + Brush for Apple iPhone 5S 5C 5, 4S 4': 67.04,
#    'Tennsco Lockers, Gray': 67.136,
#    'Fellowes Personal Hanging Folder Files, Navy': 67.15,
#    'Performers Binder/Pad Holder, Black': 67.272,
#    'Metal Folding Chairs, Beige, 4/Carton': 67.88,
#    'Berol Giant Pencil Sharpener': 67.96,
#    'Memorex 25GB 6X Branded Blu-Ray Recordable Disc, 15/Pack': 67.96,
#    'Lenovo 17-Key USB Numeric Keypad': 67.98,
#    "3M Replacement Filter for Office Air Cleaner for 20' x 33' Room": 68.256,
#    'Hand-Finished Solid Wood Document Frame': 68.46,
#    "Lock-Up Easel 'Spel-Binder'": 68.47200000000001,
#    'Xerox 1991': 68.52,
#    'Personal Creations Ink Jet Cards and Labels': 68.88,
#    'Belkin F5C206VTEL 6 Outlet Surge': 68.94,
#    'Boston KS Multi-Size Manual Pencil Sharpener': 68.97,
#    'Newell 319': 69.44,
#    'Satellite Sectional Post Binders': 69.456,
#    'Acme Hot Forged Carbon Steel Scissors with Nickel-Plated Handles, 3 7/8" Cut, 8"L': 69.5,
#    'Multi-Use Personal File Cart and Caster Set, Three Stacking Bins': 69.52,
#    'Tensor Track Tree Floor Lamp': 69.96499999999999,
#    ...}},
#  {'Postal Code': {79605: 1.3919999999999997,
#    44035: 1.8240000000000003,
#    33458: 2.064,
#    32503: 2.2140000000000004,
#    78539: 2.368,
#    32174: 2.8080000000000007,
#    93405: 3.62,
#    98208: 3.8560000000000003,
#    98002: 4.18,
#    72762: 4.3,
#    84041: 4.96,
#    80538: 5.496,
#    75150: 5.5440000000000005,
#    76248: 6.0,
#    77489: 6.369999999999998,
#    77536: 6.923999999999998,
#    52601: 7.28,
#    8901: 7.385,
#    32127: 7.824,
#    61604: 7.968,
#    59102: 8.288,
#    44221: 8.352,
#    60098: 8.849999999999998,
#    60441: 8.951999999999998,
#    67846: 9.54,
#    83501: 9.584000000000001,
#    52240: 9.99,
#    60302: 10.192000000000002,
#    16602: 10.2255,
#    77520: 10.368000000000002,
#    33161: 11.064000000000002,
#    86442: 11.144000000000002,
#    60440: 11.200000000000001,
#    92646: 11.67,
#    29730: 11.850000000000001,
#    74012: 11.88,
#    37075: 12.264,
#    35630: 12.48,
#    85281: 12.768,
#    77705: 12.768,
#    60543: 13.16,
#    78415: 13.212,
#    78501: 13.344000000000001,
#    77581: 13.392000000000001,
#    27514: 14.015999999999998,
#    60004: 14.111999999999998,
#    34952: 14.336000000000002,
#    37130: 14.352000000000002,
#    75043: 14.388,
#    75019: 14.952000000000002,
#    77803: 14.960999999999997,
#    80634: 15.176,
#    80004: 15.184000000000001,
#    77571: 15.195999999999998,
#    97123: 15.32,
#    76706: 15.544000000000002,
#    33063: 15.552000000000003,
#    33021: 15.570000000000004,
#    78666: 15.576000000000002,
#    78041: 15.872,
#    68801: 15.96,
#    28806: 16.272000000000002,
#    46368: 16.28,
#    6360: 16.770000000000003,
#    48858: 17.14,
#    68701: 17.43,
#    98006: 17.608,
#    48073: 17.67,
#    77642: 17.688000000000002,
#    14304: 17.712,
#    3060: 17.97,
#    92503: 18.02,
#    79424: 18.262,
#    95661: 18.375,
#    88220: 18.45,
#    33433: 18.464,
#    97301: 18.688,
#    75002: 18.708000000000002,
#    1453: 18.725,
#    48310: 19.0,
#    94509: 19.44,
#    28403: 19.456000000000003,
#    32137: 19.52,
#    75007: 19.567999999999998,
#    62301: 19.824,
#    98052: 19.99,
#    80229: 20.048000000000002,
#    53081: 20.085,
#    33065: 20.192,
#    28601: 20.382,
#    49423: 20.439999999999998,
#    35244: 20.725,
#    76051: 20.764000000000003,
#    37064: 20.768,
#    54302: 20.84,
#    95695: 20.928,
#    76021: 20.96,
#    6450: 21.400000000000002,
#    81001: 21.534000000000002,
#    94533: 21.560000000000002,
#    18103: 21.728,
#    19901: 21.8,
#    59715: 21.83,
#    94568: 22.0,
#    60477: 22.288,
#    45040: 22.428000000000004,
#    91360: 22.72,
#    2740: 23.18,
#    94591: 23.344,
#    92025: 23.36,
#    8401: 23.36,
#    55122: 23.625,
#    33068: 23.680000000000003,
#    97504: 23.78,
#    55901: 23.92,
#    19601: 23.968000000000004,
#    37604: 24.184,
#    60653: 24.424000000000003,
#    95051: 24.456000000000003,
#    93277: 24.560000000000002,
#    76106: 24.587999999999994,
#    98632: 24.849999999999998,
#    57401: 25.5,
#    44312: 25.560000000000002,
#    77095: 25.584000000000003,
#    58103: 25.9,
#    30328: 25.994999999999997,
#    8302: 26.205000000000002,
#    33437: 26.488500000000002,
#    60610: 26.68,
#    7050: 26.685000000000002,
#    32712: 27.018000000000008,
#    22304: 27.025,
#    43017: 27.168000000000003,
#    76117: 27.368000000000002,
#    6810: 27.46,
#    80134: 27.706000000000003,
#    90640: 27.88,
#    77506: 27.968000000000004,
#    33180: 28.176000000000002,
#    75034: 28.752000000000002,
#    75051: 28.752000000000002,
#    44107: 28.8,
#    76017: 29.145999999999994,
#    77840: 29.311999999999994,
#    54401: 29.605,
#    13021: 29.61,
#    4240: 29.84,
#    71901: 29.994999999999997,
#    60076: 30.016000000000005,
#    85635: 30.144000000000002,
#    50701: 30.32,
#    45373: 30.624000000000002,
#    43615: 30.772000000000006,
#    33317: 30.880000000000003,
#    45231: 30.96,
#    27893: 31.128000000000007,
#    66212: 31.365000000000002,
#    75220: 31.648,
#    33012: 31.9805,
#    95823: 31.983999999999998,
#    33134: 32.123999999999995,
#    68104: 32.235,
#    37918: 32.348,
#    95616: 32.400000000000006,
#    80027: 32.568,
#    92374: 32.65,
#    27405: 32.776,
#    43130: 32.896,
#    93534: 33.024,
#    19140: 33.056000000000004,
#    92404: 33.36,
#    50315: 33.465,
#    80020: 33.48800000000001,
#    11520: 33.93,
#    93905: 34.34,
#    40475: 34.5,
#    14609: 34.628,
#    7017: 34.650000000000006,
#    8360: 34.67,
#    1810: 34.87,
#    28540: 34.928000000000004,
#    27534: 34.944,
#    84604: 34.992000000000004,
#    42301: 35.59,
#    85323: 35.596000000000004,
#    92054: 35.72,
#    20016: 35.8,
#    95928: 36.44,
#    43229: 36.513000000000005,
#    91730: 36.576,
#    48640: 36.63,
#    6484: 36.665,
#    27511: 36.72800000000001,
#    92677: 37.02,
#    33710: 37.112,
#    11572: 37.209999999999994,
#    33178: 38.06400000000001,
#    75061: 38.92999999999999,
#    32114: 39.096000000000004,
#    19134: 39.27600000000001,
#    92553: 39.468,
#    1841: 39.66,
#    2148: 39.68,
#    32839: 39.72,
#    46350: 39.765,
#    55125: 39.900000000000006,
#    83642: 39.95,
#    75217: 39.984,
#    75081: 40.28099999999999,
#    72756: 40.410000000000004,
#    60623: 40.68,
#    61701: 40.684,
#    77070: 40.711999999999996,
#    37167: 40.775999999999996,
#    6460: 41.265,
#    88001: 41.37,
#    11550: 41.4,
#    48180: 41.9,
#    94061: 41.904,
#    7060: 41.95,
#    47362: 42.305,
#    19120: 42.40800000000001,
#    44060: 42.467,
#    79762: 42.784,
#    85301: 42.976,
#    57103: 43.0,
#    48066: 43.0,
#    23223: 43.04,
#    92307: 43.176,
#    2138: 43.33,
#    61832: 43.37199999999999,
#    62521: 43.464,
#    32216: 43.6,
#    21740: 43.8,
#    48185: 43.92,
#    98661: 44.02,
#    93309: 44.136,
#    33030: 44.384,
#    70065: 44.660000000000004,
#    77573: 44.716,
#    90805: 44.736000000000004,
#    28314: 44.784,
#    35601: 44.95,
#    92672: 45.028999999999996,
#    33614: 45.59400000000001,
#    19013: 45.61600000000001,
#    50322: 45.92,
#    92253: 46.32,
#    2920: 46.345,
#    39212: 46.815,
#    85023: 46.872,
#    55044: 47.18,
#    48911: 47.36,
#    54880: 47.400000000000006,
#    79907: 47.51599999999999,
#    97224: 47.70400000000001,
#    93030: 47.9,
#    33445: 47.92,
#    77041: 47.952000000000005,
#    78745: 47.984,
#    80525: 47.984,
#    6457: 48.16,
#    94110: 48.17,
#    27604: 48.384,
#    84107: 48.4,
#    12180: 48.480000000000004,
#    2895: 48.614999999999995,
#    38109: 48.656000000000006,
#    39503: 48.69,
#    31204: 48.8,
#    60423: 48.816,
#    44052: 48.896,
#    94109: 48.91,
#    24153: 49.12,
#    8701: 49.260000000000005,
#    7090: 49.3,
#    94122: 49.5,
#    85224: 49.792,
#    10009: 50.352000000000004,
#    87505: 50.46,
#    94526: 50.8,
#    92399: 50.8,
#    23602: 50.95,
#    98270: 51.09,
#    75701: 51.18399999999998,
#    22901: 51.305,
#    45503: 51.411,
#    46226: 51.75,
#    65807: 51.84,
#    70601: 51.96,
#    27360: 52.136,
#    80906: 52.416000000000004,
#    63116: 52.59,
#    38301: 53.05200000000001,
#    78550: 53.42400000000001,
#    98026: 54.042,
#    33024: 54.224000000000004,
#    61032: 54.28,
#    53186: 54.5,
#    28027: 54.792,
#    52302: 54.879999999999995,
#    49505: 54.900000000000006,
#    19143: 54.912000000000006,
#    71203: 55.0,
#    11757: 55.48,
#    22204: 55.55499999999999,
#    88101: 55.71,
#    92683: 55.76,
#    60174: 55.83,
#    33407: 55.98400000000001,
#    65203: 56.395,
#    47150: 56.699999999999996,
#    90278: 57.084,
#    68025: 57.12,
#    47905: 57.885000000000005,
#    48104: 57.959999999999994,
#    48183: 58.050000000000004,
#    44105: 58.141000000000005,
#    33801: 58.356,
#    11561: 58.5,
#    10701: 59.519999999999996,
#    75056: 59.751999999999995,
#    84057: 59.80800000000001,
#    2169: 59.97,
#    72401: 59.98,
#    6708: 59.98,
#    13501: 60.235,
#    10801: 60.72,
#    42420: 60.82,
#    98031: 60.988,
#    72209: 60.989999999999995,
#    75104: 61.188,
#    98105: 61.38,
#    27707: 61.568,
#    43123: 61.79399999999999,
#    2151: 61.96,
#    80112: 62.028,
#    84321: 62.048,
#    10024: 62.13,
#    32303: 62.19200000000001,
#    10035: 62.24,
#    90045: 62.515,
#    63301: 62.54,
#    6824: 62.94,
#    44256: 62.982,
#    29203: 63.435,
#    74133: 63.81,
#    7002: 63.96,
#    59601: 63.980000000000004,
#    55369: 64.475,
#    28110: 64.70400000000001,
#    90049: 64.74000000000001,
#    37211: 64.784,
#    89115: 64.9,
#    13440: 64.981,
#    22153: 65.22,
#    90004: 65.568,
#    80013: 65.58000000000001,
#    17403: 65.584,
#    90032: 65.61,
#    45011: 65.664,
#    7501: 65.84,
#    84106: 65.86,
#    91104: 66.36,
#    84084: 66.69,
#    98115: 66.725,
#    47201: 66.925,
#    55407: 67.15,
#    7109: 67.255,
#    43302: 67.303,
#    47374: 67.4,
#    37620: 67.56,
#    30318: 67.8,
#    28205: 67.9425,
#    97477: 67.952,
#    48601: 68.105,
#    27834: 68.112,
#    85345: 68.15400000000001,
#    95240: 68.49,
#    54601: 68.64,
#    19711: 68.66,
#    55124: 68.97,
#    77036: 69.12,
#    31907: 69.17,
#    37042: 69.21600000000001,
#    48127: 70.09,
#    10011: 70.12,
#    36608: 70.98,
#    44240: 71.976,
#    98103: 71.98,
#    55016: 72.17999999999999,
#    80122: 72.29400000000001,
#    23434: 72.43,
#    38401: 73.12800000000001,
#    98042: 73.45,
#    77340: 73.548,
#    21215: 74.0,
#    60505: 74.345,
#    33142: 74.352,
#    45014: 74.352,
#    7960: 74.45,
#    90036: 74.712,
#    30344: 75.0,
#    72701: 75.08500000000001,
#    94403: 75.17999999999999,
#    94513: 75.938,
#    92024: 76.12,
#    20707: 76.295,
#    57701: 76.32000000000001,
#    97405: 76.368,
#    92630: 76.37,
#    19805: 77.55,
#    47401: 78.35,
#    78664: 78.85279999999999,
#    20735: 79.36,
#    60540: 79.476,
#    49201: 79.82,
#    93727: 79.91,
#    85204: 81.6515,
#    92037: 81.702,
#    92236: 81.775,
#    35810: 81.92,
#    67212: 81.96,
#    64118: 82.17,
#    89502: 82.239,
#    85234: 82.368,
#    6010: 83.25,
#    48227: 84.99,
#    17602: 85.713,
#    46514: 85.715,
#    70506: 85.98,
#    89431: 86.19999999999999,
#    65109: 86.62,
#    44134: 87.032,
#    90008: 87.71,
#    1852: 87.725,
#    35401: 87.85000000000001,
#    94601: 88.48700000000001,
#    38134: 88.96000000000001,
#    3820: 89.19000000000001,
#    71111: 90.42999999999999,
#    20852: 90.48,
#    83605: 91.36,
#    95123: 91.8565,
#    29501: 92.19999999999999,
#    53209: 92.52,
#    37421: 93.72550000000001,
#    32935: 95.616,
#    85705: 95.989,
#    75023: 95.992,
#    89031: 96.18,
#    59405: 96.332,
#    55106: 96.41499999999999,
#    94086: 97.175,
#    80219: 98.233,
#    18018: 99.372,
#    43055: 99.488,
#    78207: 99.918,
#    91767: 99.98,
#    92105: 100.07600000000001,
#    92704: 100.126,
#    46614: 102.285,
#    3301: 102.3,
#    40214: 102.93,
#    1752: 103.32,
#    30076: 104.13,
#    87105: 104.525,
#    6040: 104.79,
#    42104: 105.905,
#    71603: 106.45500000000001,
#    66062: 107.94,
#    32725: 107.97600000000001,
#    85254: 110.304,
#    97756: 110.77300000000001,
#    2908: 110.98,
#    77301: 111.67200000000001,
#    95351: 111.79,
#    84020: 111.93,
#    2886: 111.96,
#    32771: 112.77300000000001,
#    43402: 113.15600000000002,
#    94521: 114.58000000000001,
#    2038: 114.60000000000001,
#    85364: 115.19200000000001,
#    7036: 115.36,
#    93454: 115.44,
#    60067: 116.312,
#    33311: 116.75999999999999,
#    30605: 117.445,
#    46142: 117.87,
#    48234: 119.189,
#    30080: 119.56,
#    53711: 119.585,
#    92627: 119.61600000000001,
#    92691: 120.0,
#    63122: 120.67,
#    60090: 121.536,
#    73120: 121.6,
#    40324: 121.92999999999999,
#    95336: 122.352,
#    22801: 122.48,
#    90301: 122.59,
#    92804: 122.688,
#    93010: 122.91,
#    60126: 123.924,
#    53214: 125.24000000000001,
#    46203: 125.88,
#    95037: 127.193,
#    95207: 127.86,
#    61107: 128.744,
#    95610: 129.39000000000001,
#    41042: 130.31,
#    97206: 131.264,
#    42071: 132.31,
#    48307: 132.52,
#    74403: 137.61,
#    83201: 140.376,
#    29406: 142.125,
#    79109: 142.42239999999998,
#    92592: 142.54500000000002,
#    30188: 143.32500000000002,
#    13601: 144.003,
#    22980: 144.1,
#    23464: 144.41500000000002,
#    90660: 145.9,
#    80022: 146.352,
#    99207: 149.73000000000002,
#    7601: 150.65499999999997,
#    33023: 150.712,
#    98059: 150.8,
#    60201: 150.9195,
#    61821: 151.96,
#    23320: 153.28,
#    60035: 153.584,
#    2149: 154.9,
#    98502: 155.25,
#    60025: 158.376,
#    84062: 158.9,
#    87401: 159.99,
#    37087: 163.96,
#    8861: 164.545,
#    76903: 166.838,
#    48146: 167.292,
#    27217: 167.44000000000003,
#    7011: 168.41,
#    53132: 171.55,
#    10550: 171.81,
#    21044: 174.3,
#    90712: 175.8495,
#    14215: 177.42499999999998,
#    36830: 182.03,
#    30062: 182.67000000000002,
#    91941: 183.765,
#    39401: 185.57999999999998,
#    23666: 186.54,
#    36116: 187.21499999999997,
#    91911: 192.8,
#    48205: 193.68,
#    93101: 193.92,
#    97030: 195.136,
#    89015: 196.45,
#    83704: 197.373,
#    77590: 199.304,
#    46060: 199.83999999999997,
#    20877: 202.95999999999998,
#    29483: 203.46999999999997,
#    5408: 205.03,
#    98198: 215.976,
#    7055: 216.13299999999998,
#    31088: 217.39999999999998,
#    54703: 217.76999999999998,
#    33319: 224.293,
#    38671: 234.36,
#    78521: 237.09600000000003,
#    28052: 240.774,
#    55433: 251.565,
#    60068: 254.74400000000003,
#    4401: 255.42,
#    52001: 263.96,
#    26003: 265.12,
#    80501: 266.35200000000003,
#    56560: 271.93,
#    66502: 273.96,
#    52402: 278.4,
#    76063: 279.43850000000003,
#    91761: 283.92,
#    92530: 283.92,
#    48187: 287.92,
#    48237: 290.42999999999995,
#    73505: 291.035,
#    1040: 301.96,
#    48126: 301.96,
#    72032: 301.96,
#    91776: 303.25,
#    55113: 312.375,
#    71854: 327.12,
#    96003: 333.576,
#    60016: 336.91,
#    92345: 338.23875,
#    60462: 339.96000000000004,
#    99301: 352.31999999999994,
#    61761: 366.74399999999997,
#    60188: 382.116,
#    46544: 388.12,
#    78577: 395.402,
#    53142: 399.95,
#    60089: 415.6995,
#    95687: 423.28,
#    92020: 432.808,
#    90604: 444.76800000000003,
#    73034: 479.77500000000003,
#    92563: 484.65000000000003,
#    59801: 487.98400000000004,
#    29464: 545.9399999999999,
#    87124: 557.096,
#    83301: 574.4029999999999,
#    56301: 603.92,
#    75080: 644.2320000000002,
#    73071: 675.6650000000001,
#    63376: 697.16,
#    1915: 704.25,
#    90503: 742.736,
#    34741: 751.984,
#    84043: 758.363,
#    54915: 835.655,
#    98226: 1099.5,
#    64055: 1208.685,
#    91505: 1279.968,
#    82001: 1603.1360000000002,
#    14701: 2354.395}}]

# %%
City='Lakeland'
State='Florida'
Postal_Code= 33801
Sub_Category= 'Storage'
Discount= 0.2
Product_Name= 'Fellowes High-Stak Drawer Files'
Quantity= 4
Shipping_days=1
Ship_Mode= 'First Class'
Segment= 'Corporate'
Region= 'South'
Category= 'Office Supplies'
